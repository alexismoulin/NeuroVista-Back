# %%
import pydicom
import pathlib

# %%
test_dicom = pathlib.Path("../SUBJECTS/Alexis/ST1/SE1/DICOM/IMG0.dcm")
pydicom.dcmread(fp=test_dicom)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 198
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.311.159162803110630512050473338463448516062
# (0002,0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 2.16.56.465769650.1.1.4.96
# (0002,0013) Implementation Version Name         SH: 'tmpTool.4.96'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008,0008) Image Type                          CS: ['DERIVED', 'SECONDARY', 'REFORMATTED', 'AVERAGE']
# (0008,0012) Instance Creation Date              DA: '20220929'
# (0008,0013) Instance Creation Time              TM: '172937.292'
# ...
